# %% [markdown]
# <a href="https://colab.research.google.com/github/rajnoel922-hub/PREDICT-HEIGHT/blob/main/EXP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv('/content/height.csv')

# %%
data.head()
# Out:
#    gender  height  weight
# 0       0      72     155
# 1       0      67     145
# 2       0      65     125
# 3       1      67     120
# 4       1      63     105

# %%
x=data['weight'].values.reshape(-1,1)
y=data['height'].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()#importing libraries
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
weight=float(input("Enter weight in kg"))
predicted_height=model.predict([[weight]])
print("Predicted height is",predicted_height)
# Out:
# Enter weight in kg65
# Predicted height is [59.07588286]

# %%
#plotting output
plt.scatter(x1_test,y1_test)
plt.plot(x1_test,y1_pred,color='red')
plt.xlabel("Actual weight")
plt.ylabel("Predicted value")
plt.show()

# %%
x1=data['height'].values.reshape(-1,1)
y1=data['weight'].values

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2,random_state=42)

# %%
model=LinearRegression()#importing libraries
model.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_pred=model.predict(x1_test)

# %%
height=float(input("Enter height in cm"))
predicted_weight=model.predict([[weight]])
print("Predicted weight is",predicted_weight)
# Out:
# Enter height in cm170
# Predicted weight is [136.05236958]

# %%
#plotting output
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,color='red')
plt.xlabel("Actual height")
plt.ylabel("Predicted value")
plt.show()
